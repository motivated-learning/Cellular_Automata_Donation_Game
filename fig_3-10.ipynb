# %% [markdown]
# ### FIGURE 3

# %%
from utils import figure3

# rules to plot; rule is any integer value between 0-255
rules = [251, 219, 243, 187, 195, 153, 90, 50, 48, 34, 18, 72]
figure3(rules=rules, size=50, steps=50)

# %% [markdown]
# ### FIGURE 4
#
# Parameters have been set to improve the speed of execution.

# %%
from utils import figure4

rules = [243, 153, 219, 195, 251, 187, 50, 48, 34, 90, 72, 18]
figure4(rules=rules, steps=100, size=100, repeats=2)
# Out:
# Results for rules
# 0% [████████████████████████] 100% | ETA: 00:00:00
# Total time elapsed: 00:03:59

# %% [markdown]
# ### FIGURE 5

# %%
from utils import figure56

rules = [243, 90, 50, 18]
figure56(rules=rules, slower_walking=False, size=100, steps=300)

# %% [markdown]
# ### Figure 6

# %%
rules = [243, 90, 50, 18]
figure56(rules=rules, slower_walking=True, size=100, steps=300)

# %% [markdown]
# ### FIGURE 7
#
# Parameters have been set to improve the speed of execution.

# %%
from utils import figure7

rules = [153, 219, 195, 251, 243, 187, 50, 48, 34, 90, 72, 18]
figure7(rules=rules, size=100, steps=300, repeats=2)
# Out:
# Results for rules
# 0% [██████████████████████████████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:07

# %% [markdown]
# ### FIGURE 8
#
# Parameters have been set to improve the speed of execution.

# %%
from utils import figure8

rules = [153, 219, 195, 251, 243, 187, 50, 48, 34, 90, 72, 18]
figure8(rules=rules, size=100, steps=300, repeats=2)
# Out:
# Results for rules
# 0% [██████████████████████████████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:13

# %% [markdown]
# ### FIGURE 10
#
# Parameters have been set to improve the speed of execution.

# %%
from utils import run_evolution, figure9a, figure9b

rules = [153, 219, 195, 251, 243, 187, 50, 48, 34, 90, 72, 18]
ev_generations = 100
history_number_of_agents_vs_evolution_step = run_evolution(rules=rules, size=100, steps=300, ev_generations=ev_generations)
figure9a(rules, history_number_of_agents_vs_evolution_step, ev_generations)
figure9b(rules, history_number_of_agents_vs_evolution_step)
# Out:
# Evolution
# 0% [██████████████████████████████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
